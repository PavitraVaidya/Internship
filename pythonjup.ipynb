# %%
# !pip install pandas numpy scipy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\pavit\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\pavit\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: scipy in c:\users\pavit\appdata\roaming\python\python313\site-packages (1.15.3)
# Requirement already satisfied: matplotlib in c:\users\pavit\appdata\roaming\python\python313\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\pavit\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\pavit\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
# Set the aesthetics for the plots
sns.set(style="whitegrid")

# %%
from sklearn.datasets import load_iris
# Load the Iris dataset
iris_data = load_iris()
iris_df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
iris_df['species'] = iris_data.target
# Map species target values to species names
iris_df['species'] = iris_df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(iris_df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df.hist(bins=20, figsize=(14, 10))
plt.show()
# Pairplot for visualizing relationships between features
sns.pairplot(iris_df, hue='species')
plt.show()

# %%
setosa = iris_df[iris_df['species'] == 'setosa']
versicolor = iris_df[iris_df['species'] == 'versicolor']
# Perform a t-test
t_stat, p_val = stats.ttest_ind(setosa['sepal length (cm)'], versicolor['sepal length (cm)'])
print(f"T-statistic: {t_stat}, P-value: {p_val}")
# Out:
# T-statistic: -10.52098626754911, P-value: 8.985235037487079e-18

# %%
f_stat, p_val = stats.f_oneway(
iris_df[iris_df['species'] == 'setosa']['sepal length (cm)'],
iris_df[iris_df['species'] == 'versicolor']['sepal length (cm)'],
iris_df[iris_df['species'] == 'virginica']['sepal length (cm)']
)
print(f"F-statistic: {f_stat}, P-value: {p_val}")
# Out:
# F-statistic: 119.26450218450468, P-value: 1.669669190769383e-31

# %%
correlation_matrix = iris_df.select_dtypes(include='number').corr()
# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
